# %% [markdown]
# <img src="./images/weiailogo2.png"
#      style="float: right"
#      width=150
#      style="padding-bottom:30px;"/>
# <br>
#
# <img style="float: left;" src= "./images/python-logo.svg" width="400">
# <img  style="float: center;" src="./images/jupyter-logo.svg" width="130">
#
#
# #  Zoom-able and Resize-able Interative Plot in Jupyter Notebook
#
# ## Sigmund S. Wei, Ph.D. Professor

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt


# define an array x of 32 uniformly spaced floating point
# values from 0 to 4π
x = np.linspace(0,4*np.pi,32)

# define y as the array containing the sine values from x
y = np.sin(x)

# create the plot
fig,ax = plt.subplots()
ax.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">
